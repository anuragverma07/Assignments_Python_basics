# %% [markdown]
# 1.What is Python, and why is it popular?
#
# Python is a high-level, interpreted programming language known for its readability, simplicity, and versatility. It is popular due to its vast libraries, community support, and use in web development, data science, AI, and automation.
#
# 2.What is an interpreter in Python?
#
# The interpreter is a program that executes Python code line by line, converting it into machine-readable instructions.
#
# 3.What are pre-defined keywords in Python?
#
# Pre-defined keywords are reserved words in Python (e.g., if, else, for, while, def) that have specific meanings and cannot be used as variable names.
#
# 4.Can keywords be used as variable names?
#
# No, Python keywords cannot be used as variable names.
#
# 5.What is mutability in Python?
#
# Mutability refers to whether an object’s value can be changed after creation. Mutable objects can change, while immutable objects cannot.
#
# 6.Why are lists mutable, but tuples are immutable?
#
# Lists allow modifications (adding, removing, updating elements), while tuples do not, ensuring data integrity and performance optimization.
#
# 7.What is the difference between == and is operators in Python?
#
# == checks for value equality, while is checks for object identity (whether they refer to the same memory location).
#
# 8.What are logical operators in Python?
#
# Logical operators (and, or, not) combine multiple conditions in boolean expressions.
#
# 9.What is type casting in Python?
#
# Type casting converts one data type into another (e.g., int("10") converts a string to an integer).
#
# 10.What is the difference between implicit and explicit type casting?
#
# Implicit casting is done automatically by Python (e.g., int to float). Explicit casting is done manually using functions like int(), float(), str().
#
# 11.What is the purpose of conditional statements in Python?
#
# Conditional statements (if, elif, else) control the flow of execution based on conditions.
#
# 12.How does the elif statement work?
#
# elif (short for "else if") allows multiple conditions to be checked sequentially after an if statement.
#
# 13.What is the difference between for and while loops?
#
# for loops iterate over a sequence (list, range, etc.), while while loops run as long as a condition remains true.
#
# 14.Describe a scenario where a while loop is more suitable than a for loop.
#
# A while loop is better when the number of iterations is unknown, such as waiting for user input or running a program until a specific condition is met.

# %%
# 1. Print "Hello, World!"
print("Hello, World!")

# 2. Display your name and age
name = "Anurag"
age = 23
print(f"My name is Ram and I am 26 years old.")

# 3. Print all pre-defined keywords using the keyword library
import keyword
print(keyword.kwlist)

# 4. Check if a given word is a Python keyword
word = input("Enter a word: ")
print(f"{word} is a keyword: {keyword.iskeyword(word)}")

# 5. Demonstrate difference in mutability (list vs. tuple)
my_list = [1, 2, 3]
my_tuple = (1, 2, 3)
my_list[0] = 10  # Works
# my_tuple[0] = 10  # Error: Tuples are immutable

# 6. Function to demonstrate mutable (list) and immutable (int) arguments
def test_mutability(immutable, mutable):
    immutable += 1
    mutable.append(4)
    print("Immutable inside function:", immutable)
    print("Mutable inside function:", mutable)

num = 5
lst = [1, 2, 3]
test_mutability(num, lst)
print("Outside function:", num, lst)

# 7. Demonstrate logical operators
x, y = True, False
print(x and y, x or y, not x)

# 8. Convert user input to int, float, and boolean
user_input = input("Enter a value: ")
print(int(user_input), float(user_input), bool(user_input))

# 9. Type casting with list elements
nums = ["1", "2", "3"]
nums_int = list(map(int, nums))
print(nums_int)

# 10. Check if a number is positive, negative, or zero
num = int(input("Enter a number: "))
if num > 0:
    print("Positive")
elif num < 0:
    print("Negative")
else:
    print("Zero")

# 11. Print numbers from 1 to 100 using a for loop
for i in range(1, 101):
    print(i, end=" ")

# 12. Sum of all even numbers between 1 and 500
print(sum(i for i in range(1, 501) if i % 2 == 0))

# 13. Reverse a string using a while loop
s = input("Enter a string: ")
reversed_s = ""
i = len(s) - 1
while i >= 0:
    reversed_s += s[i]
    i -= 1
print("Reversed string:", reversed_s)

# 14. Factorial of a number using a while loop
num = int(input("Enter a number: "))
factorial = 1
while num > 1:
    factorial *= num
    num -= 1
print("Factorial:", factorial)
